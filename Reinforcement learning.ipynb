# %%
from torch import nn
from torch.distributions import Categorical
import torch
import torch.optim as optim
import gym
import numpy as np

# Dicount Factor
gamma = 0.99

class Pi(nn.Module):
  def __init__(self, in_dim, out_dim):
    super(Pi, self).__init__()
    layers = [
        nn.Linear(in_dim, 64),
        nn.ReLU(),
        nn.Linear(64, out_dim),
        ]
    self.model = nn.Sequential(*layers)
    self.onpolicy_reset()
    self.train() 
  
  # Initialize log_probs & rewards
  def onpolicy_reset(self):
    self.log_probs = []
    self.rewards = []
  
  # Calculate Propagation based on the state of Agent
  def forward(self, x):
    pdparam = self.model(x)
    return pdparam

  # By taking the state as a factor, call forward(), calculate it
    # and Select the action as a sample
  # log_probs according to the action are calulated and stored
  def act(self, state):
    x = torch.from_numpy(state.astype(np.float32))  # Convert to numpy to tensor
    pdparam = self.forward(x)                       # Forward pass      
    pd = Categorical(logits=pdparam)                # Probability Distribution
    action = pd.sample()                            # Sampling one action from pd
    log_prob = pd.log_prob(action)                  # Calculate log_probs
    self.log_probs.append(log_prob)                 # Store log_probs
    return action.item()

# %%
def train(pi, optimizer):
  # Inner gradient-ascent loop of REINFORCE algorithm
  T = len(pi.rewards)                  # Total number of rewards received durning the episode
  rets = np.empty(T, dtype=np.float32) # Array to store the returns
  future_ret = 0.0                     # Intialize Future return
  
  # Compute the returns efficiently
  for t in reversed(range(T)):
    future_ret = pi.rewards[t] + gamma * future_ret
    rets[t] = future_ret

  # Convert to Pytorch tensor  
  rets = torch.tensor(rets)
  log_probs = torch.stack(pi.log_probs)

  # Calculate Loss Sum
  loss = - log_probs * rets # gradient term; Negative for maximizing
  loss = torch.sum(loss)

  # Backpropagation & Optimization
  optimizer.zero_grad()     # Clear previous gradients
  loss.backward()           # Compute gradients via backpropagation
  optimizer.step()          # Update policy parameters using gradients
  return loss

# %%
def main():
  # Initialize Environment & Network
  env = gym.make('CartPole-v0')           # Call the Environment
  in_dim = env.observation_space.shape[0] # 4
  out_dim = env.action_space.n            # 2
  pi = Pi(in_dim, out_dim)                # policy pi_theta for REINFORCE
  optimizer = optim.Adam(pi.parameters(), lr=0.01)
  
  # Episode Loop
  for epi in range(300):
    state, _ = env.reset()
    # Time Step Loop
    for t in range(200): 
      action = pi.act(state) # Action Sampling
      next_state, reward, terminated, truncated, _ = env.step(action) # Calculate Next State & Reward
      done = terminated or truncated
      pi.rewards.append(reward) # Store Reward 
      env.render()
      state = next_state
      if done:
        break
    loss = train(pi, optimizer) # train per episode
    total_reward = sum(pi.rewards)
    solved = total_reward > 195.0
    pi.onpolicy_reset() # onpolicy: clear memory after training
    
    print(f'Episode {epi}, loss: {loss}, \
    total_reward: {total_reward}, solved: {solved}')
    
if __name__ == '__main__':
  main()
# Out:
# C:\Users\isang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# C:\Users\isang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\envs\classic_control\cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(
# Episode 0, loss: 42.46593475341797,     total_reward: 11.0, solved: False
# Episode 1, loss: 150.3479766845703,     total_reward: 21.0, solved: False
# Episode 2, loss: 189.4750518798828,     total_reward: 24.0, solved: False
# Episode 3, loss: 323.60150146484375,     total_reward: 31.0, solved: False
# Episode 4, loss: 119.0931625366211,     total_reward: 18.0, solved: False
# Episode 5, loss: 41.036399841308594,     total_reward: 11.0, solved: False
# Episode 6, loss: 85.41355895996094,     total_reward: 15.0, solved: False
# Episode 7, loss: 652.3286743164062,     total_reward: 47.0, solved: False
# Episode 8, loss: 2879.379150390625,     total_reward: 109.0, solved: False
# Episode 9, loss: 160.1590576171875,     total_reward: 22.0, solved: False
# Episode 10, loss: 1074.5362548828125,     total_reward: 62.0, solved: False
# Episode 11, loss: 114.58767700195312,     total_reward: 18.0, solved: False
# Episode 12, loss: 70.17330932617188,     total_reward: 13.0, solved: False
# Episode 13, loss: 182.4623565673828,     total_reward: 24.0, solved: False
# Episode 14, loss: 279.5957946777344,     total_reward: 30.0, solved: False
# Episode 15, loss: 679.5098876953125,     total_reward: 49.0, solved: False
# Episode 16, loss: 1121.656005859375,     total_reward: 63.0, solved: False
# Episode 17, loss: 1176.4832763671875,     total_reward: 67.0, solved: False
# Episode 18, loss: 62.80339431762695,     total_reward: 13.0, solved: False
# Episode 19, loss: 166.3319091796875,     total_reward: 23.0, solved: False
# Episode 20, loss: 83.24357604980469,     total_reward: 15.0, solved: False
# Episode 21, loss: 957.7691040039062,     total_reward: 60.0, solved: False
# Episode 22, loss: 177.05126953125,     total_reward: 24.0, solved: False
# Episode 23, loss: 2539.151123046875,     total_reward: 104.0, solved: False
# Episode 24, loss: 1580.7396240234375,     total_reward: 80.0, solved: False
# Episode 25, loss: 869.24658203125,     total_reward: 56.0, solved: False
# Episode 26, loss: 91.0941162109375,     total_reward: 16.0, solved: False
# Episode 27, loss: 751.5831909179688,     total_reward: 53.0, solved: False
# Episode 28, loss: 6108.88134765625,     total_reward: 182.0, solved: False
# Episode 29, loss: 1305.46728515625,     total_reward: 73.0, solved: False
# Episode 30, loss: 1158.5625,     total_reward: 66.0, solved: False
# Episode 31, loss: 456.9958801269531,     total_reward: 41.0, solved: False
# Episode 32, loss: 1981.72802734375,     total_reward: 94.0, solved: False
# Episode 33, loss: 2424.7333984375,     total_reward: 107.0, solved: False
# Episode 34, loss: 894.3746948242188,     total_reward: 60.0, solved: False
# Episode 35, loss: 4171.1845703125,     total_reward: 149.0, solved: False
# Episode 36, loss: 1640.076904296875,     total_reward: 84.0, solved: False
# Episode 37, loss: 826.811279296875,     total_reward: 58.0, solved: False
# Episode 38, loss: 1729.883544921875,     total_reward: 88.0, solved: False
# Episode 39, loss: 4502.369140625,     total_reward: 155.0, solved: False
# Episode 40, loss: 1487.22802734375,     total_reward: 82.0, solved: False
# Episode 41, loss: 3602.519287109375,     total_reward: 135.0, solved: False
# Episode 42, loss: 6010.009765625,     total_reward: 192.0, solved: False
# Episode 43, loss: 3331.873046875,     total_reward: 133.0, solved: False
# Episode 44, loss: 4012.66943359375,     total_reward: 157.0, solved: False
# Episode 45, loss: 6447.421875,     total_reward: 200.0, solved: True
# Episode 46, loss: 5164.2373046875,     total_reward: 174.0, solved: False
# Episode 47, loss: 3499.49560546875,     total_reward: 139.0, solved: False
# Episode 48, loss: 4846.8505859375,     total_reward: 178.0, solved: False
# Episode 49, loss: 2113.680419921875,     total_reward: 100.0, solved: False
# Episode 50, loss: 5386.482421875,     total_reward: 185.0, solved: False
# Episode 51, loss: 1680.06494140625,     total_reward: 88.0, solved: False
# Episode 52, loss: 2184.365234375,     total_reward: 103.0, solved: False
# Episode 53, loss: 3638.534423828125,     total_reward: 147.0, solved: False
# Episode 54, loss: 3202.2353515625,     total_reward: 131.0, solved: False
# Episode 55, loss: 5084.27880859375,     total_reward: 180.0, solved: False
# Episode 56, loss: 5638.1904296875,     total_reward: 195.0, solved: False
# Episode 57, loss: 5590.64404296875,     total_reward: 200.0, solved: True
# Episode 58, loss: 5795.24267578125,     total_reward: 200.0, solved: True
# Episode 59, loss: 5510.68212890625,     total_reward: 200.0, solved: True
# Episode 60, loss: 5615.35205078125,     total_reward: 200.0, solved: True
# Episode 61, loss: 5344.56640625,     total_reward: 200.0, solved: True
# Episode 62, loss: 5763.4267578125,     total_reward: 200.0, solved: True
# Episode 63, loss: 5575.57275390625,     total_reward: 200.0, solved: True
# Episode 64, loss: 5469.7490234375,     total_reward: 200.0, solved: True
# Episode 65, loss: 5118.3955078125,     total_reward: 200.0, solved: True
# Episode 66, loss: 5740.09228515625,     total_reward: 200.0, solved: True
# Episode 67, loss: 5466.232421875,     total_reward: 200.0, solved: True
# Episode 68, loss: 5535.625,     total_reward: 200.0, solved: True
# Episode 69, loss: 5201.18408203125,     total_reward: 200.0, solved: True
# Episode 70, loss: 4576.2275390625,     total_reward: 200.0, solved: True
# Episode 71, loss: 5157.947265625,     total_reward: 200.0, solved: True
# Episode 72, loss: 5354.86669921875,     total_reward: 200.0, solved: True
# Episode 73, loss: 5008.10009765625,     total_reward: 200.0, solved: True
# Episode 74, loss: 4763.54296875,     total_reward: 200.0, solved: True
# Episode 75, loss: 5263.0078125,     total_reward: 200.0, solved: True
# Episode 76, loss: 5464.0048828125,     total_reward: 200.0, solved: True
# Episode 77, loss: 5795.46533203125,     total_reward: 200.0, solved: True
# Episode 78, loss: 5520.77294921875,     total_reward: 200.0, solved: True
# Episode 79, loss: 5443.1171875,     total_reward: 200.0, solved: True
# Episode 80, loss: 3904.5634765625,     total_reward: 174.0, solved: False
# Episode 81, loss: 4710.7587890625,     total_reward: 189.0, solved: False
# Episode 82, loss: 2675.890625,     total_reward: 140.0, solved: False
# Episode 83, loss: 2925.90576171875,     total_reward: 142.0, solved: False
# Episode 84, loss: 2362.514892578125,     total_reward: 114.0, solved: False
# Episode 85, loss: 1713.0125732421875,     total_reward: 106.0, solved: False
# Episode 86, loss: 2401.79296875,     total_reward: 130.0, solved: False
# Episode 87, loss: 2555.35107421875,     total_reward: 129.0, solved: False
# Episode 88, loss: 1102.3507080078125,     total_reward: 77.0, solved: False
# Episode 89, loss: 2302.10986328125,     total_reward: 120.0, solved: False
# Episode 90, loss: 1542.53369140625,     total_reward: 96.0, solved: False
# Episode 91, loss: 1420.585205078125,     total_reward: 95.0, solved: False
# Episode 92, loss: 781.4013671875,     total_reward: 71.0, solved: False
# Episode 93, loss: 498.3075866699219,     total_reward: 49.0, solved: False
# Episode 94, loss: 1519.00439453125,     total_reward: 104.0, solved: False
# Episode 95, loss: 1872.4342041015625,     total_reward: 105.0, solved: False
# Episode 96, loss: 1115.5201416015625,     total_reward: 73.0, solved: False
# Episode 97, loss: 963.3046264648438,     total_reward: 69.0, solved: False
# Episode 98, loss: 1996.468994140625,     total_reward: 114.0, solved: False
# Episode 99, loss: 1392.4241943359375,     total_reward: 102.0, solved: False
# Episode 100, loss: 1356.9466552734375,     total_reward: 95.0, solved: False
# Episode 101, loss: 1453.25048828125,     total_reward: 101.0, solved: False
# Episode 102, loss: 1860.42822265625,     total_reward: 111.0, solved: False
# Episode 103, loss: 1034.2022705078125,     total_reward: 82.0, solved: False
# Episode 104, loss: 2410.23291015625,     total_reward: 122.0, solved: False
# Episode 105, loss: 2468.523193359375,     total_reward: 125.0, solved: False
# Episode 106, loss: 2332.878662109375,     total_reward: 116.0, solved: False
# Episode 107, loss: 4356.16162109375,     total_reward: 175.0, solved: False
# Episode 108, loss: 1922.577392578125,     total_reward: 117.0, solved: False
# Episode 109, loss: 2236.912353515625,     total_reward: 120.0, solved: False
# Episode 110, loss: 3652.493896484375,     total_reward: 175.0, solved: False
# Episode 111, loss: 2634.190185546875,     total_reward: 142.0, solved: False
# Episode 112, loss: 2532.377197265625,     total_reward: 128.0, solved: False
# Episode 113, loss: 1798.5849609375,     total_reward: 112.0, solved: False
# Episode 114, loss: 2247.239990234375,     total_reward: 126.0, solved: False
# Episode 115, loss: 2628.105224609375,     total_reward: 132.0, solved: False
# Episode 116, loss: 2370.6630859375,     total_reward: 138.0, solved: False
# Episode 117, loss: 1673.237060546875,     total_reward: 101.0, solved: False
# Episode 118, loss: 1299.833740234375,     total_reward: 81.0, solved: False
# Episode 119, loss: 1295.91552734375,     total_reward: 97.0, solved: False
# Episode 120, loss: 1079.04052734375,     total_reward: 83.0, solved: False
# Episode 121, loss: 2126.64990234375,     total_reward: 115.0, solved: False
# Episode 122, loss: 2734.79248046875,     total_reward: 155.0, solved: False
# Episode 123, loss: 997.3724365234375,     total_reward: 87.0, solved: False
# Episode 124, loss: 948.8995971679688,     total_reward: 81.0, solved: False
# Episode 125, loss: 1232.5556640625,     total_reward: 85.0, solved: False
# Episode 126, loss: 1160.369384765625,     total_reward: 93.0, solved: False
# Episode 127, loss: 1681.8074951171875,     total_reward: 100.0, solved: False
# Episode 128, loss: 1206.5992431640625,     total_reward: 89.0, solved: False
# Episode 129, loss: 902.2659912109375,     total_reward: 80.0, solved: False
# Episode 130, loss: 2518.46533203125,     total_reward: 144.0, solved: False
# Episode 131, loss: 1312.8150634765625,     total_reward: 106.0, solved: False
# Episode 132, loss: 1341.5914306640625,     total_reward: 95.0, solved: False
# Episode 133, loss: 691.5894165039062,     total_reward: 64.0, solved: False
# Episode 134, loss: 1522.224609375,     total_reward: 99.0, solved: False
# Episode 135, loss: 644.0137939453125,     total_reward: 70.0, solved: False
# Episode 136, loss: 2261.8857421875,     total_reward: 140.0, solved: False
# Episode 137, loss: 1834.9949951171875,     total_reward: 113.0, solved: False
# Episode 138, loss: 1981.283935546875,     total_reward: 124.0, solved: False
# Episode 139, loss: 1755.7177734375,     total_reward: 114.0, solved: False
# Episode 140, loss: 1530.75732421875,     total_reward: 104.0, solved: False
# Episode 141, loss: 2439.5693359375,     total_reward: 137.0, solved: False
# Episode 142, loss: 2604.188232421875,     total_reward: 133.0, solved: False
# Episode 143, loss: 2396.30859375,     total_reward: 133.0, solved: False
# Episode 144, loss: 1835.146484375,     total_reward: 120.0, solved: False
# Episode 145, loss: 2402.306640625,     total_reward: 124.0, solved: False
# Episode 146, loss: 2648.4716796875,     total_reward: 129.0, solved: False
# Episode 147, loss: 3111.083984375,     total_reward: 169.0, solved: False
# Episode 148, loss: 2496.479248046875,     total_reward: 124.0, solved: False
# Episode 149, loss: 3058.99072265625,     total_reward: 159.0, solved: False
# Episode 150, loss: 4148.12646484375,     total_reward: 180.0, solved: False
# Episode 151, loss: 2645.83056640625,     total_reward: 137.0, solved: False
# Episode 152, loss: 2098.924560546875,     total_reward: 123.0, solved: False
# Episode 153, loss: 2460.757080078125,     total_reward: 132.0, solved: False
# Episode 154, loss: 2370.72314453125,     total_reward: 117.0, solved: False
# Episode 155, loss: 2911.27490234375,     total_reward: 156.0, solved: False
# Episode 156, loss: 3223.549072265625,     total_reward: 154.0, solved: False
# Episode 157, loss: 3695.313232421875,     total_reward: 158.0, solved: False
# Episode 158, loss: 2822.12255859375,     total_reward: 137.0, solved: False
# Episode 159, loss: 4485.86083984375,     total_reward: 181.0, solved: False
# Episode 160, loss: 3862.18408203125,     total_reward: 160.0, solved: False
# Episode 161, loss: 5127.43017578125,     total_reward: 198.0, solved: True
# Episode 162, loss: 4696.0654296875,     total_reward: 198.0, solved: True
# Episode 163, loss: 4125.0048828125,     total_reward: 176.0, solved: False
# Episode 164, loss: 3814.0244140625,     total_reward: 167.0, solved: False
# Episode 165, loss: 5419.02880859375,     total_reward: 200.0, solved: True
# Episode 166, loss: 4674.5634765625,     total_reward: 191.0, solved: False
# Episode 167, loss: 4295.33837890625,     total_reward: 200.0, solved: True
# Episode 168, loss: 5320.81591796875,     total_reward: 200.0, solved: True
# Episode 169, loss: 4535.9794921875,     total_reward: 182.0, solved: False
# Episode 170, loss: 4258.580078125,     total_reward: 200.0, solved: True
# Episode 171, loss: 5429.326171875,     total_reward: 200.0, solved: True
# Episode 172, loss: 5349.14501953125,     total_reward: 200.0, solved: True
# Episode 173, loss: 4476.59326171875,     total_reward: 200.0, solved: True
# Episode 174, loss: 4815.4189453125,     total_reward: 200.0, solved: True
# Episode 175, loss: 5528.533203125,     total_reward: 200.0, solved: True
# Episode 176, loss: 3424.606689453125,     total_reward: 165.0, solved: False
# Episode 177, loss: 4820.150390625,     total_reward: 200.0, solved: True
# Episode 178, loss: 4406.384765625,     total_reward: 200.0, solved: True
# Episode 179, loss: 5185.22607421875,     total_reward: 200.0, solved: True
# Episode 180, loss: 4097.0947265625,     total_reward: 200.0, solved: True
# Episode 181, loss: 5351.9169921875,     total_reward: 200.0, solved: True
# Episode 182, loss: 4747.19970703125,     total_reward: 200.0, solved: True
# Episode 183, loss: 4629.4296875,     total_reward: 200.0, solved: True
# Episode 184, loss: 4356.232421875,     total_reward: 200.0, solved: True
# Episode 185, loss: 4853.9140625,     total_reward: 200.0, solved: True
# Episode 186, loss: 4030.308837890625,     total_reward: 200.0, solved: True
# Episode 187, loss: 4917.53125,     total_reward: 200.0, solved: True
# Episode 188, loss: 4935.408203125,     total_reward: 200.0, solved: True
# Episode 189, loss: 4757.4462890625,     total_reward: 200.0, solved: True
# Episode 190, loss: 3509.861328125,     total_reward: 171.0, solved: False
# Episode 191, loss: 3707.922119140625,     total_reward: 182.0, solved: False
# Episode 192, loss: 2812.519775390625,     total_reward: 155.0, solved: False
# Episode 193, loss: 4129.04736328125,     total_reward: 186.0, solved: False
# Episode 194, loss: 4420.5400390625,     total_reward: 194.0, solved: False
# Episode 195, loss: 5341.3232421875,     total_reward: 200.0, solved: True
# Episode 196, loss: 5496.916015625,     total_reward: 200.0, solved: True
# Episode 197, loss: 5014.6005859375,     total_reward: 200.0, solved: True
# Episode 198, loss: 1159.9766845703125,     total_reward: 83.0, solved: False
# Episode 199, loss: 5091.24169921875,     total_reward: 200.0, solved: True
# Episode 200, loss: 4336.5986328125,     total_reward: 200.0, solved: True
# Episode 201, loss: 1605.196533203125,     total_reward: 105.0, solved: False
# Episode 202, loss: 4722.916015625,     total_reward: 200.0, solved: True
# Episode 203, loss: 5173.27490234375,     total_reward: 200.0, solved: True
# Episode 204, loss: 4328.3994140625,     total_reward: 200.0, solved: True
# Episode 205, loss: 4539.47265625,     total_reward: 200.0, solved: True
# Episode 206, loss: 4679.1787109375,     total_reward: 200.0, solved: True
# Episode 207, loss: 4965.62255859375,     total_reward: 200.0, solved: True
# Episode 208, loss: 4444.50830078125,     total_reward: 200.0, solved: True
# Episode 209, loss: 5094.3603515625,     total_reward: 200.0, solved: True
# Episode 210, loss: 4983.900390625,     total_reward: 200.0, solved: True
# Episode 211, loss: 5733.5146484375,     total_reward: 200.0, solved: True
# Episode 212, loss: 4796.49267578125,     total_reward: 200.0, solved: True
# Episode 213, loss: 5389.978515625,     total_reward: 200.0, solved: True
# Episode 214, loss: 5817.8359375,     total_reward: 200.0, solved: True
# Episode 215, loss: 5212.23046875,     total_reward: 193.0, solved: False
# Episode 216, loss: 5118.025390625,     total_reward: 200.0, solved: True
# Episode 217, loss: 5729.81298828125,     total_reward: 200.0, solved: True
# Episode 218, loss: 4744.4365234375,     total_reward: 200.0, solved: True
# Episode 219, loss: 5578.5546875,     total_reward: 200.0, solved: True
# Episode 220, loss: 5150.6640625,     total_reward: 200.0, solved: True
# Episode 221, loss: 5094.22021484375,     total_reward: 200.0, solved: True
# Episode 222, loss: 2073.67138671875,     total_reward: 104.0, solved: False
# Episode 223, loss: 5382.47119140625,     total_reward: 200.0, solved: True
# Episode 224, loss: 5065.75439453125,     total_reward: 200.0, solved: True
# Episode 225, loss: 5197.87646484375,     total_reward: 200.0, solved: True
# Episode 226, loss: 5213.2099609375,     total_reward: 200.0, solved: True
# Episode 227, loss: 4898.296875,     total_reward: 200.0, solved: True
# Episode 228, loss: 5410.9140625,     total_reward: 200.0, solved: True
# Episode 229, loss: 4818.41796875,     total_reward: 200.0, solved: True
# Episode 230, loss: 4879.22265625,     total_reward: 200.0, solved: True
# Episode 231, loss: 5482.88818359375,     total_reward: 200.0, solved: True
# Episode 232, loss: 4409.44189453125,     total_reward: 193.0, solved: False
# Episode 233, loss: 5371.40234375,     total_reward: 200.0, solved: True
# Episode 234, loss: 5764.2685546875,     total_reward: 200.0, solved: True
# Episode 235, loss: 4919.27294921875,     total_reward: 200.0, solved: True
# Episode 236, loss: 4862.6298828125,     total_reward: 200.0, solved: True
# Episode 237, loss: 4016.490478515625,     total_reward: 183.0, solved: False
# Episode 238, loss: 1217.169677734375,     total_reward: 87.0, solved: False
# Episode 239, loss: 4805.6103515625,     total_reward: 200.0, solved: True
# Episode 240, loss: 5183.97265625,     total_reward: 200.0, solved: True
# Episode 241, loss: 1328.447509765625,     total_reward: 100.0, solved: False
# Episode 242, loss: 5131.3232421875,     total_reward: 200.0, solved: True
# Episode 243, loss: 4661.041015625,     total_reward: 200.0, solved: True
# Episode 244, loss: 4204.142578125,     total_reward: 200.0, solved: True
# Episode 245, loss: 4234.8330078125,     total_reward: 173.0, solved: False
# Episode 246, loss: 3178.457275390625,     total_reward: 160.0, solved: False
# Episode 247, loss: 4852.1650390625,     total_reward: 200.0, solved: True
# Episode 248, loss: 4746.99267578125,     total_reward: 197.0, solved: True
# Episode 249, loss: 4396.56396484375,     total_reward: 193.0, solved: False
# Episode 250, loss: 3939.71435546875,     total_reward: 175.0, solved: False
# Episode 251, loss: 4239.9453125,     total_reward: 189.0, solved: False
# Episode 252, loss: 2832.74560546875,     total_reward: 143.0, solved: False
# Episode 253, loss: 1970.616943359375,     total_reward: 109.0, solved: False
# Episode 254, loss: 2809.900390625,     total_reward: 153.0, solved: False
# Episode 255, loss: 1449.8203125,     total_reward: 103.0, solved: False
# Episode 256, loss: 2191.6220703125,     total_reward: 123.0, solved: False
# Episode 257, loss: 1307.7958984375,     total_reward: 109.0, solved: False
# Episode 258, loss: 1558.8101806640625,     total_reward: 109.0, solved: False
# Episode 259, loss: 1687.641845703125,     total_reward: 105.0, solved: False
# Episode 260, loss: 1729.60302734375,     total_reward: 95.0, solved: False
# Episode 261, loss: 497.8946228027344,     total_reward: 58.0, solved: False
# Episode 262, loss: 1538.8929443359375,     total_reward: 98.0, solved: False
# Episode 263, loss: 1279.68359375,     total_reward: 108.0, solved: False
# Episode 264, loss: 1273.8807373046875,     total_reward: 103.0, solved: False
# Episode 265, loss: 1611.2877197265625,     total_reward: 105.0, solved: False
# Episode 266, loss: 323.1303405761719,     total_reward: 44.0, solved: False
# Episode 267, loss: 346.86602783203125,     total_reward: 47.0, solved: False
# Episode 268, loss: 371.05206298828125,     total_reward: 50.0, solved: False
# Episode 269, loss: 221.7542724609375,     total_reward: 34.0, solved: False
# Episode 270, loss: 251.4827880859375,     total_reward: 41.0, solved: False
# Episode 271, loss: 165.42845153808594,     total_reward: 35.0, solved: False
# Episode 272, loss: 1256.967529296875,     total_reward: 98.0, solved: False
# Episode 273, loss: 601.8856201171875,     total_reward: 54.0, solved: False
# Episode 274, loss: 152.5592803955078,     total_reward: 38.0, solved: False
# Episode 275, loss: 1265.62841796875,     total_reward: 105.0, solved: False
# Episode 276, loss: 1500.2432861328125,     total_reward: 109.0, solved: False
# Episode 277, loss: 1619.703369140625,     total_reward: 102.0, solved: False
# Episode 278, loss: 1561.8895263671875,     total_reward: 104.0, solved: False
# Episode 279, loss: 1613.3328857421875,     total_reward: 102.0, solved: False
# Episode 280, loss: 394.3926696777344,     total_reward: 47.0, solved: False
# Episode 281, loss: 1439.86572265625,     total_reward: 100.0, solved: False
# Episode 282, loss: 1698.8988037109375,     total_reward: 111.0, solved: False
# Episode 283, loss: 1467.4554443359375,     total_reward: 111.0, solved: False
# Episode 284, loss: 419.0594177246094,     total_reward: 49.0, solved: False
# Episode 285, loss: 1861.884521484375,     total_reward: 119.0, solved: False
# Episode 286, loss: 1250.4879150390625,     total_reward: 102.0, solved: False
# Episode 287, loss: 1766.5599365234375,     total_reward: 115.0, solved: False
# Episode 288, loss: 1782.9486083984375,     total_reward: 115.0, solved: False
# Episode 289, loss: 1838.649169921875,     total_reward: 112.0, solved: False
# Episode 290, loss: 1592.601806640625,     total_reward: 113.0, solved: False
# Episode 291, loss: 2039.4267578125,     total_reward: 125.0, solved: False
# Episode 292, loss: 1867.4022216796875,     total_reward: 113.0, solved: False
# Episode 293, loss: 315.1628112792969,     total_reward: 38.0, solved: False
# Episode 294, loss: 1872.46435546875,     total_reward: 110.0, solved: False
# Episode 295, loss: 1801.120361328125,     total_reward: 126.0, solved: False
# Episode 296, loss: 2142.933837890625,     total_reward: 128.0, solved: False
# Episode 297, loss: 2011.51025390625,     total_reward: 133.0, solved: False
# Episode 298, loss: 1618.895751953125,     total_reward: 123.0, solved: False
# Episode 299, loss: 2287.964111328125,     total_reward: 132.0, solved: False
